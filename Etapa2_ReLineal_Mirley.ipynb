# %% [markdown]
# Ejercicio de Regresión Lineal Mirley Ramirez

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:/Users/0JIT0S/OneDrive/Escritorio/data.csv", sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.columns
data.info
data.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
data.plot.scatter(x="metro",y="precio")
plt.show()

# %%
modelo=regresion.fit(years,data["precio"])
print("Interseccion (b)", modelo.intercept_)
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
entrada=[[5.0],[15.0],[20.0],[25.0]]
predicciones=modelo.predict(entrada)
print(predicciones)
# Out:
# [389.48571429 445.94285714 474.17142857 502.4       ]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos originales')
plt.scatter(entrada, predicciones, color='purple')
plt.plot(entrada,predicciones,color='red',label='lineade regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
